# %%
import psycopg2
import pandas as pd

# %%
conn = psycopg2.connect(
   database="d65103c5a2kbgs", 
    user='u16ifm924gr2m8', 
    password='pe4029f0ba1fbaafd034f4dbf17f703bf9a5d6c8420f07719f5db4054c9d4da40', 
    host='c1gvrf2q90nbcq.cluster-czrs8kj4isg7.us-east-1.rds.amazonaws.com', 
    port = '5432'
    
)
cursor = conn.cursor()

# %%
sql = '''SELECT * from modified_label'''
data = pd.read_sql_query(sql, conn)
# Out:
# /var/folders/f5/vn3dt39d3hl4z6fvrlqn3s300000gp/T/ipykernel_2451/913544206.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query(sql, conn)

# %%
len(data)
# Out:
# 3723

# %%
data
# Out:
#                                       uuid user_id  \
# 0     56d81429-97f5-4dac-8eec-aed5f430d506  4vQZBQ
# 1     a5b223ca-7006-406a-96b7-900447c71fc4  USzArg
# 2     8742b6b1-a92e-4aec-920d-673e779ddc8c  USzArg
# 3     91786a5f-f376-41e9-8e93-038c9ef8fb74  YtYC5w
# 4     3e847b65-9b87-41bf-b4ef-488a0271ebc4  USzArg
# ...                                    ...     ...
# 3718  fde6b37f-7c95-48d7-b2e3-332c6baaf866  USzArg
# 3719  9dc29b73-6126-460f-a890-d00de9d55958  USzArg
# 3720  95e33825-5f8e-4ae0-a629-7a431074170d  USzArg
# 3721  d6ba990e-647e-491e-8eee-fc14d64e9c41  USzArg
# 3722  6812a037-7c1f-418c-86c8-abb058204ba5  USzArg
#
#                                                   docid  \
# 0     LLM-AggreFact:DqeLab1jnlXl51TV6g3fEIphiWL9btS0...
# 1     LLM-AggreFact:qw1pBWz5ynI76U121ehgtFXQXzIGP5lw...
# 2     LLM-AggreFact:q56mHW6cfwgyKnrPD79U1HaTv2YaBZuP...
# 3     LLM-AggreFact:Q93Y9kC2QHHtQbdTNTouc7bXcTFWJCzp...
# 4     LLM-AggreFact:kvgYpbrK7d3F0wr6E4e9bznPh7DWgVBl...
# ...

# %%
spans_docid = list(data[data['docid'] == 'ACIBENCH-D2N098:llama70b-ul2']['nonfactual_span'])
{span: spans_docid.count(span) for span in set(spans_docid)}
# Out:
# {'conducted a physical examination': 1, None: 3, 'visited a doctor': 1}

# %%
data.to_csv('/Users/ramprasad.sa/hallucinations_annotations_trial/annotated_data/database_dump_hallu_trial_Feb_8_2025.csv')

# %%
data
# Out:
#                                       uuid user_id  \
# 0     56d81429-97f5-4dac-8eec-aed5f430d506  4vQZBQ
# 1     a5b223ca-7006-406a-96b7-900447c71fc4  USzArg
# 2     8742b6b1-a92e-4aec-920d-673e779ddc8c  USzArg
# 3     91786a5f-f376-41e9-8e93-038c9ef8fb74  YtYC5w
# 4     3e847b65-9b87-41bf-b4ef-488a0271ebc4  USzArg
# ...                                    ...     ...
# 3718  fde6b37f-7c95-48d7-b2e3-332c6baaf866  USzArg
# 3719  9dc29b73-6126-460f-a890-d00de9d55958  USzArg
# 3720  95e33825-5f8e-4ae0-a629-7a431074170d  USzArg
# 3721  d6ba990e-647e-491e-8eee-fc14d64e9c41  USzArg
# 3722  6812a037-7c1f-418c-86c8-abb058204ba5  USzArg
#
#                                                   docid  \
# 0     LLM-AggreFact:DqeLab1jnlXl51TV6g3fEIphiWL9btS0...
# 1     LLM-AggreFact:qw1pBWz5ynI76U121ehgtFXQXzIGP5lw...
# 2     LLM-AggreFact:q56mHW6cfwgyKnrPD79U1HaTv2YaBZuP...
# 3     LLM-AggreFact:Q93Y9kC2QHHtQbdTNTouc7bXcTFWJCzp...
# 4     LLM-AggreFact:kvgYpbrK7d3F0wr6E4e9bznPh7DWgVBl...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 doc[4:21]
#
# NameError: name 'doc' is not defined
