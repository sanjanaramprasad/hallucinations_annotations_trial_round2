# %%
import psycopg2
import pandas as pd

# %%
conn = psycopg2.connect(
   database="d65103c5a2kbgs", 
    user='u16ifm924gr2m8', 
    password='pe4029f0ba1fbaafd034f4dbf17f703bf9a5d6c8420f07719f5db4054c9d4da40', 
    host='c1gvrf2q90nbcq.cluster-czrs8kj4isg7.us-east-1.rds.amazonaws.com', 
    port = '5432'
    
)
cursor = conn.cursor()

# %%
sql = '''SELECT * from modified_label'''
data = pd.read_sql_query(sql, conn)
# Out:
# /var/folders/f5/vn3dt39d3hl4z6fvrlqn3s300000gp/T/ipykernel_76085/913544206.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query(sql, conn)

# %%
len(data)
# Out:
# 4364

# %%
xsum_data = data[data['origin'] == 'XSUM']
xsum_data[xsum_data['user_id'] == 'c']
# Out:
#                                      uuid user_id                       docid  \
# 478  6056d646-7849-4d86-aac0-9b4699992146  4vQZBQ  XSUM-34017556:llama70b-ul2
# 479  aa83732f-b908-44d4-b291-5eda22136e80  4vQZBQ      XSUM-34017556:gpt4-ul2
# 480  fe3b18f1-03ca-42a3-a565-edcb93093793  4vQZBQ      XSUM-34017556:gpt4-ul2
# 481  bb01c712-cdf8-4e7d-b4de-dce0472e1d4b  4vQZBQ      XSUM-34017556:gpt4-ul2
# 482  6a9fdef3-cb81-4361-bf81-86966cde76f5  4vQZBQ      XSUM-34017556:gpt4-ul2
# 503  8fef3ffe-0a04-4710-814b-c042f7a6e450  4vQZBQ      XSUM-12889429:gpt4-ul2
# 504  394beeb3-36e2-4219-8ab2-666172f01944  4vQZBQ  XSUM-12889429:llama70b-ul2
# 505  c510e4a6-e001-45eb-9360-e22ed1b753af  4vQZBQ  XSUM-12889429:llama70b-ul2
# 510  74ff3235-cb12-4490-9873-8a630a1fcf37  4vQZBQ  XSUM-35441162:llama70b-ul2
# 512  1f15ab88-c4ec-4177-a829-5ce8a5f7d9b1  4vQZBQ      XSUM-29928061:gpt4-ul2
# 513  48cccf49-e208-4e8d-a9f6-f82e1daa7f4d  4vQZBQ      XSUM-28345611:gpt4-ul2
# ...

# %%
data[data['docid'] == 'ACIBENCH-D2N092:mistral7b-ul2']
# Out:
#                                       uuid user_id  \
# 1961  b0f60d86-9582-4672-af1d-c33969a9a104  4vQZBQ
# 2155  0103a22d-518b-4d7c-b600-581bc85e17d7  g7wLBw
# 2700  aaf2d042-56a1-420d-bd23-b951ce64e44b  YtYC5w
# 2702  d838c1be-a0ba-4d62-bdda-4add7c3093d3  YtYC5w
# 3021  715b40ca-e6fc-4ee1-aa68-2918ccc3dc94  USzArg
#
#                               docid  \
# 1961  ACIBENCH-D2N092:mistral7b-ul2
# 2155  ACIBENCH-D2N092:mistral7b-ul2
# 2700  ACIBENCH-D2N092:mistral7b-ul2
# 2702  ACIBENCH-D2N092:mistral7b-ul2
# 3021  ACIBENCH-D2N092:mistral7b-ul2
#
#                                                  source  \
# 1961  [doctor] hello , mrs .\nMartinez .\nGood to se...
# 2155  [doctor] hello , mrs .\nMartinez .\nGood to se...
# 2700  [doctor] hello , mrs .\nMartinez .\nGood to se...
# 2702  [doctor] hello , mrs .\nMartinez .\nGood to se...
# 3021  [doctor] hello , mrs .\nMartinez .\nGood to se...
#
#                                                 summary      model  \
# ...

# %%
# data_genaudit = data[data['benchmark_dataset_name'] == 'genaudit']

shortlisted_annotators = ['g7wLBw', 'YtYC5w', '4vQZBQ', 'USzArg']

# %%
data_all = data[data['user_id'].isin(shortlisted_annotators)]
len(data_all)
# Out:
# 4364

# %%
data_all.to_csv('/Users/ramprasad.sa/hallucinations_annotations_trial/annotated_data/database_dump_hallu_trial_Mar_7_2025.csv')

# %%
data
# Out:
#                                       uuid user_id  \
# 0     56d81429-97f5-4dac-8eec-aed5f430d506  4vQZBQ
# 1     a5b223ca-7006-406a-96b7-900447c71fc4  USzArg
# 2     8742b6b1-a92e-4aec-920d-673e779ddc8c  USzArg
# 3     91786a5f-f376-41e9-8e93-038c9ef8fb74  YtYC5w
# 4     3e847b65-9b87-41bf-b4ef-488a0271ebc4  USzArg
# ...                                    ...     ...
# 4359  292af26a-c061-4129-aab7-1672a7e986df  YtYC5w
# 4360  b23962af-ef6c-4222-8667-8bdb4e389459  YtYC5w
# 4361  f16887c8-647d-48ee-b650-7ae773ef25de  YtYC5w
# 4362  6dc14a26-9833-4db0-94bf-b1b969ad3e3c  YtYC5w
# 4363  b05a6095-1723-45bb-b1b8-ef274487b156  YtYC5w
#
#                                                   docid  \
# 0     LLM-AggreFact:DqeLab1jnlXl51TV6g3fEIphiWL9btS0...
# 1     LLM-AggreFact:qw1pBWz5ynI76U121ehgtFXQXzIGP5lw...
# 2     LLM-AggreFact:q56mHW6cfwgyKnrPD79U1HaTv2YaBZuP...
# 3     LLM-AggreFact:Q93Y9kC2QHHtQbdTNTouc7bXcTFWJCzp...
# 4     LLM-AggreFact:kvgYpbrK7d3F0wr6E4e9bznPh7DWgVBl...
# ...

# %%
set(data['benchmark_dataset_name'])
# Out:
# {'ExpertQA',
#  'RAGTruth',
#  'TofuEval-MediaS',
#  'TofuEval-MeetB',
#  'Wice',
#  'genaudit'}

# %%
data[data['benchmark_dataset_name'] == 'RAGTruth']
# Out:
#                                       uuid user_id  \
# 12    8742b6b1-a92e-4aec-920d-673e779ddc8c  USzArg
# 16    3e847b65-9b87-41bf-b4ef-488a0271ebc4  USzArg
# 211   9791afb6-48ce-4b63-982d-06f67784f395  YtYC5w
# 237   89b6d30a-9b0b-4f9a-b305-604050e12c49  USzArg
# 243   080f013f-e5b6-448a-be29-89d5c8d4385f  USzArg
# ...                                    ...     ...
# 1965  a59b2be3-5d8a-49c6-97a5-3144b6ab2bc0  USzArg
# 1966  8cc04448-7b87-4745-8b78-9d851bace9fa  USzArg
# 1967  38aaa9b0-4ff7-499c-8121-6757d0947356  USzArg
# 1968  d3ea7e23-e6df-48d1-90be-585b0798d7af  USzArg
# 1969  5f272f42-5d38-4354-ad2b-db309dfb1d95  USzArg
#
#                                                   docid  \
# 12    LLM-AggreFact:q56mHW6cfwgyKnrPD79U1HaTv2YaBZuP...
# 16    LLM-AggreFact:kvgYpbrK7d3F0wr6E4e9bznPh7DWgVBl...
# 211   LLM-AggreFact:OJ744memBaaVb3r0baDKcJIamfOfLLmb...
# 237   LLM-AggreFact:IeuG3MIrisUMkxG1boz04DbOmJag4hMt...
# 243   LLM-AggreFact:nuHdWGtmTsikmMG9EOkjGHPwvxgAw7yK...
# ...
